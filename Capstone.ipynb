# %%
#Importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pylab import rcParams
import seaborn as sns
sns.set_style('darkgrid')
rcParams['figure.figsize'] = 8,8
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
#loading the csv file
train_dataset = pd.read_csv('Train.csv')
test_dataset = pd.read_csv('Test (1).csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 #loading the csv file
# ----> 2 train_dataset = pd.read_csv('Train.csv')
#       3 test_dataset = pd.read_csv('Test (1).csv')
#
# ...

# %%
train_dataset.head(2)
# Out:
#                                     user_id REGION        TENURE  MONTANT  \
# 0  7ee9e11e342e27c70455960acc80d3f91c1286d1  DAKAR  K > 24 month  20000.0
# 1  50443f42bdc92b10388fc56e520e4421a5fa655c    NaN  K > 24 month      NaN
#
#    FREQUENCE_RECH  REVENUE  ARPU_SEGMENT  FREQUENCE  DATA_VOLUME  ON_NET  \
# 0            47.0  21602.0        7201.0       52.0       8835.0  3391.0
# 1             NaN      NaN           NaN        NaN          NaN     NaN
#
#    ORANGE   TIGO  ZONE1  ZONE2 MRG  REGULARITY  \
# 0   396.0  185.0    NaN    NaN  NO          62
# 1     NaN    NaN    NaN    NaN  NO           3
#
#                          TOP_PACK  FREQ_TOP_PACK  CHURN
# 0  On net 200F=Unlimited _call24H           30.0      0
# 1                             NaN            NaN      0

# %%
train_dataset['TOP_PACK'].unique()
# Out:
# array(['On net 200F=Unlimited _call24H', nan, 'Data:490F=1GB,7d',
#        'All-net 500F=2000F;5d', 'On-net 500=4000,10d',
#        'Data:3000F=10GB,30d', 'Data:200F=Unlimited,24H',
#        'IVR Echat_Daily_50F', 'Data:1000F=2GB,30d',
#        'Mixt 250F=Unlimited_call24H', 'On-net 1000F=10MilF;10d',
#        'MIXT:500F= 2500F on net _2500F off net;2d',
#        'Data: 200 F=100MB,24H', 'All-net 600F= 3000F ;5d',
#        'On-net 200F=60mn;1d', 'Twter_U2opia_Daily',
#        'Data: 100 F=40MB,24H', 'All-net 500F =2000F_AllNet_Unlimited',
#        'On net 200F= 3000F_10Mo ;24H', '200=Unlimited1Day', 'Jokko_Daily',
#        'Data:1000F=5GB,7d', 'Data:700F=1.5GB,7d', 'All-net 1000=5000;5d',
#        'Data:150F=SPPackage1,24H', 'IVR Echat_Monthly_500F',
#        'VAS(IVR_Radio_Daily)', 'MIXT: 390F=04HOn-net_400SMS_400 Mo;4h\t',
#        'MIXT: 200mnoff net _unl on net _5Go;30d', 'On-net 500F_FNF;3d',
#        'MIXT: 590F=02H_On-net_200SMS_200 Mo;24h\t\t',
# ...

# %%
train_dataset['REGION'].unique()
# Out:
# array(['DAKAR', nan, 'SAINT-LOUIS', 'THIES', 'LOUGA', 'MATAM', 'FATICK',
#        'KAOLACK', 'DIOURBEL', 'TAMBACOUNDA', 'ZIGUINCHOR', 'KOLDA',
#        'KAFFRINE', 'SEDHIOU', 'KEDOUGOU'], dtype=object)

# %%
train_dataset['MRG'].unique()
# Out:
# array(['NO'], dtype=object)

# %%
train_dataset['TOP_PACK'].unique()
# Out:
# array(['On net 200F=Unlimited _call24H', nan, 'Data:490F=1GB,7d',
#        'All-net 500F=2000F;5d', 'On-net 500=4000,10d',
#        'Data:3000F=10GB,30d', 'Data:200F=Unlimited,24H',
#        'IVR Echat_Daily_50F', 'Data:1000F=2GB,30d',
#        'Mixt 250F=Unlimited_call24H', 'On-net 1000F=10MilF;10d',
#        'MIXT:500F= 2500F on net _2500F off net;2d',
#        'Data: 200 F=100MB,24H', 'All-net 600F= 3000F ;5d',
#        'On-net 200F=60mn;1d', 'Twter_U2opia_Daily',
#        'Data: 100 F=40MB,24H', 'All-net 500F =2000F_AllNet_Unlimited',
#        'On net 200F= 3000F_10Mo ;24H', '200=Unlimited1Day', 'Jokko_Daily',
#        'Data:1000F=5GB,7d', 'Data:700F=1.5GB,7d', 'All-net 1000=5000;5d',
#        'Data:150F=SPPackage1,24H', 'IVR Echat_Monthly_500F',
#        'VAS(IVR_Radio_Daily)', 'MIXT: 390F=04HOn-net_400SMS_400 Mo;4h\t',
#        'MIXT: 200mnoff net _unl on net _5Go;30d', 'On-net 500F_FNF;3d',
#        'MIXT: 590F=02H_On-net_200SMS_200 Mo;24h\t\t',
# ...

# %%
train_dataset['TENURE'].unique()
# Out:
# array(['K > 24 month', 'E 6-9 month', 'H 15-18 month', 'G 12-15 month',
#        'I 18-21 month', 'J 21-24 month', 'F 9-12 month', 'D 3-6 month'],
#       dtype=object)

# %%
train_dataset['REGULARITY'].unique()
# Out:
# array([62,  3,  1, 61, 56,  6, 10,  2, 16, 43,  8, 18, 12, 24, 54, 29, 14,
#        40, 23, 52, 60, 34, 13, 46, 47, 31,  9, 58, 38, 36, 19,  5, 39, 55,
#        27,  4, 32, 26, 17, 48, 22, 53, 59, 20, 44,  7, 41, 49, 33, 42, 28,
#        30, 15, 57, 21, 11, 45, 50, 25, 37, 51, 35], dtype=int64)

# %%
train_dataset.shape
# Out:
# (1077024, 19)

# %%
#identifying the various datatypes
train_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1077024 entries, 0 to 1077023
# Data columns (total 19 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   user_id         1077024 non-null  object
#  1   REGION          652687 non-null   object
#  2   TENURE          1077024 non-null  object
#  3   MONTANT         699139 non-null   float64
#  4   FREQUENCE_RECH  699139 non-null   float64
#  5   REVENUE         714669 non-null   float64
#  6   ARPU_SEGMENT    714669 non-null   float64
#  7   FREQUENCE       714669 non-null   float64
#  8   DATA_VOLUME     547261 non-null   float64
#  9   ON_NET          683850 non-null   float64
#  10  ORANGE          629880 non-null   float64
#  11  TIGO            432250 non-null   float64
#  12  ZONE1           84898 non-null    float64
#  13  ZONE2           68794 non-null    float64
#  14  MRG             1077024 non-null  object
#  15  REGULARITY      1077024 non-null  int64
# ...

# %%
train_dataset.describe().T
# Out:
#                     count         mean           std   min     25%     50%  \
# MONTANT          699139.0  5529.210895   7104.737952  20.0  1000.0  3000.0
# FREQUENCE_RECH   699139.0    11.523756     13.261938   1.0     2.0     7.0
# REVENUE          714669.0  5506.050798   7175.625010   1.0  1000.0  3000.0
# ARPU_SEGMENT     714669.0  1835.355961   2391.870902   0.0   333.0  1000.0
# FREQUENCE        714669.0    13.974439     14.687059   1.0     3.0     9.0
# DATA_VOLUME      547261.0  3368.801722  12898.928039   0.0     0.0   258.0
# ON_NET           683850.0   277.065798    874.315378   0.0     5.0    27.0
# ORANGE           629880.0    95.160804    203.020261   0.0     7.0    29.0
# TIGO             432250.0    23.105018     64.035464   0.0     2.0     6.0
# ZONE1             84898.0     8.167483     39.245883   0.0     0.0     1.0
# ZONE2             68794.0     7.709844     36.090513   0.0     0.0     2.0
# ...

# %%
train_dataset.isna().sum()
# Out:
# user_id                 0
# REGION             424337
# TENURE                  0
# MONTANT            377885
# FREQUENCE_RECH     377885
# REVENUE            362355
# ARPU_SEGMENT       362355
# FREQUENCE          362355
# DATA_VOLUME        529763
# ON_NET             393174
# ORANGE             447144
# TIGO               644774
# ZONE1              992126
# ZONE2             1008230
# MRG                     0
# REGULARITY              0
# TOP_PACK           450895
# FREQ_TOP_PACK      450895
# CHURN                   0
# dtype: int64

# %%
train_dataset[train_dataset.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [user_id, REGION, TENURE, MONTANT, FREQUENCE_RECH, REVENUE, ARPU_SEGMENT, FREQUENCE, DATA_VOLUME, ON_NET, ORANGE, TIGO, ZONE1, ZONE2, MRG, REGULARITY, TOP_PACK, FREQ_TOP_PACK, CHURN]
# Index: []

# %% [markdown]
# Univariate Analysis

# %%
train_dataset['REGION'].value_counts().plot(kind='bar', figsize=(10,5), ylabel='Counts', xlabel='REGION')
plt.show()

# %%
train_dataset['TENURE'].value_counts().plot(kind='bar', figsize=(10,5))
plt.ylabel('Counts')
plt.xlabel('TENURE')
plt.show()

# %%
churn_counts = train_dataset['CHURN'].value_counts()
churn_counts.plot(kind='bar', figsize=(10,5))
plt.ylabel('Counts')
plt.xlabel('Churn')
plt.show()

# %%
len(train_dataset['TOP_PACK'].unique())
# Out:
# 127

# %%
train_dataset['TOP_PACK'].value_counts().plot(kind='bar', figsize=(10,5))
plt.ylabel('Counts')
plt.xlabel('TOP_PACK')
plt.show()
# Out:
# c:\Users\afari\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# Bi-Variate Analysis

# %%
correlation = train_dataset.corr(numeric_only=True)
correlation
# Out:
#                  MONTANT  FREQUENCE_RECH   REVENUE  ARPU_SEGMENT  FREQUENCE  \
# MONTANT         1.000000        0.791875  0.976696      0.976696   0.776145
# FREQUENCE_RECH  0.791875        1.000000  0.798738      0.798737   0.955882
# REVENUE         0.976696        0.798738  1.000000      1.000000   0.786208
# ARPU_SEGMENT    0.976696        0.798737  1.000000      1.000000   0.786207
# FREQUENCE       0.776145        0.955882  0.786208      0.786207   1.000000
# DATA_VOLUME     0.307393        0.158125  0.313408      0.313408   0.174710
# ON_NET          0.324712        0.403519  0.329744      0.329744   0.392982
# ORANGE          0.656019        0.519295  0.659143      0.659144   0.472755
# TIGO            0.409970        0.341645  0.408489      0.408489   0.305933
# ZONE1           0.374499        0.116630  0.384992      0.384992   0.110514
# ZONE2           0.421718        0.125633  0.390504      0.390504   0.142466
# ...

# %%
sns.heatmap(data=correlation, annot=True, cmap='bwr')
# Out:
# <Axes: >

# %%
data=train_dataset[['REGULARITY', 'CHURN','REVENUE','FREQUENCE']]

sns.pairplot(data, palette= {1:'seagreen', 0:'skyblue'}, hue = 'CHURN')
plt.show()

# %%
train_dataset.head(1)
# Out:
#                                     user_id REGION        TENURE  MONTANT  \
# 0  7ee9e11e342e27c70455960acc80d3f91c1286d1  DAKAR  K > 24 month  20000.0
#
#    FREQUENCE_RECH  REVENUE  ARPU_SEGMENT  FREQUENCE  DATA_VOLUME  ON_NET  \
# 0            47.0  21602.0        7201.0       52.0       8835.0  3391.0
#
#    ORANGE   TIGO  ZONE1  ZONE2 MRG  REGULARITY  \
# 0   396.0  185.0    NaN    NaN  NO          62
#
#                          TOP_PACK  FREQ_TOP_PACK  CHURN
# 0  On net 200F=Unlimited _call24H           30.0      0

# %%
#checking for outliers
outlier_columns = ['REVENUE','MONTANT', 'FREQUENCE_RECH','ARPU_SEGMENT','FREQUENCE', 'DATA_VOLUME','ON_NET',	'ORANGE'	,'TIGO']

#ploting 
plt.figure(figsize=(10, 6))
plt.boxplot(train_dataset[outlier_columns].values, labels=outlier_columns)
plt.title('Outliers in column')
plt.ylabel('Values')
plt.show()

# %%
train_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1077024 entries, 0 to 1077023
# Data columns (total 19 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   user_id         1077024 non-null  object
#  1   REGION          652687 non-null   object
#  2   TENURE          1077024 non-null  object
#  3   MONTANT         699139 non-null   float64
#  4   FREQUENCE_RECH  699139 non-null   float64
#  5   REVENUE         714669 non-null   float64
#  6   ARPU_SEGMENT    714669 non-null   float64
#  7   FREQUENCE       714669 non-null   float64
#  8   DATA_VOLUME     547261 non-null   float64
#  9   ON_NET          683850 non-null   float64
#  10  ORANGE          629880 non-null   float64
#  11  TIGO            432250 non-null   float64
#  12  ZONE1           84898 non-null    float64
#  13  ZONE2           68794 non-null    float64
#  14  MRG             1077024 non-null  object
#  15  REGULARITY      1077024 non-null  int64
# ...

# %%
plt.boxplot(train_dataset)

# %%
sns.boxplot(train_dataset,x=[['REVENUE', 'FREQUENCE']])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 sns.boxplot(train_dataset,x=[['REVENUE', 'FREQUENCE']])
#
# File c:\Users\afari\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:1582, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1574 def boxplot(
#    1575     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    1576     orient=None, color=None, palette=None, saturation=.75, fill=True,
#    (...)
#    1579     legend="auto", ax=None, **kwargs
#    1580 ):
# -> 1582     p = _CategoricalPlotter(
#    1583         data=data,
#    1584         variables=dict(x=x, y=y, hue=hue),
#    1585         order=order,
# ...
